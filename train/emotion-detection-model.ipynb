# %% [markdown]
# # Facial emotion recogition model

# %% [markdown]
# ### Import the required Libraries

# %%
import os
import random
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.layers import Flatten, Dense, Dropout, MaxPooling2D, BatchNormalization, Conv2D, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ### Dataset Analysis

# %%
import os
dataset_path = "/kaggle/input/fer2013"
# List the contents of the dataset directory
print(os.listdir(dataset_path))
# Out:
# ['test', 'train']

# %%
# create the path for dataset directories
train_data_dir = '/kaggle/input/fer2013/train'
validation_data_dir = '/kaggle/input/fer2013/test'

# %%
# List the different emotions of the FER2013 dataset
train_expressions = os.listdir(train_data_dir)
validation_expressions = os.listdir(validation_data_dir)

print("Emotion Categories in Train set:", train_expressions)
print("Emotion Categories in Test set:", validation_expressions)
# Out:
# Emotion Categories in Train set: ['surprise', 'fear', 'angry', 'neutral', 'sad', 'disgust', 'happy']
# Emotion Categories in Test set: ['surprise', 'fear', 'angry', 'neutral', 'sad', 'disgust', 'happy']

# %%
# Dictionaries to store the image counts
train_image_counts = {expr: 0 for expr in train_expressions}
validation_image_counts = {expr: 0 for expr in validation_expressions}

# Count the number of images for each emotion category
for expr in train_expressions:
    train_image_counts[expr] = len(os.listdir(os.path.join(train_data_dir, expr)))

for expr in validation_expressions:
    validation_image_counts[expr] = len(os.listdir(os.path.join(validation_data_dir, expr)))
    
# Calculate the total number of images in the training and testing sets
total_train_images = sum(train_image_counts.values())
total_validation_images = sum(validation_image_counts.values())

# Print the counts of the images in the sets
print("\nNumber of Images per Category in Training Set:")
for expr, count in train_image_counts.items():
    print(f"{expr}: {count}")
print(f"Total Training Images: {total_train_images}")

print("\nNumber of Images per Category in Validation Set:")
for expr, count in validation_image_counts.items():
    print(f"{expr}: {count}")
print(f"Total Validation Images: {total_validation_images}")
# Out:
# Number of Images per Category in Training Set:
# surprise: 3171
# fear: 4097
# angry: 3995
# neutral: 4965
# sad: 4830
# disgust: 436
# happy: 7215
# Total Training Images: 28709
#
# Number of Images per Category in Validation Set:
# surprise: 831
# fear: 1024
# angry: 958
# neutral: 1233
# sad: 1247
# disgust: 111
# happy: 1774
# Total Validation Images: 7178

# %%
# visualize the images from the dataset
emotions = os.listdir(train_data_dir)
plt.figure(figsize=(12, 6))

for i, emotion in enumerate(emotions, 1):
    folder = os.path.join(train_data_dir, emotion)
    img_path = os.path.join(folder, os.listdir(folder)[20])
    
    img = plt.imread(img_path)
    plt.subplot(2, 4, i)
    plt.imshow(img, cmap='gray')
    plt.title(emotion)
    plt.axis('off')

plt.show()

# %%
# Plot the dataset distribution as a graph
plt.figure(figsize=(8, 6))
colors=sns.color_palette("tab10")
plt.bar(validation_image_counts.keys(), validation_image_counts.values(), color=colors)
plt.title("Dataset Distribution", fontsize=18)
plt.xlabel("Emotion Category", fontsize=13)
plt.ylabel("Number of Images", fontsize=13)
plt.xticks(rotation=0)
plt.yticks([])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Data preparation

# %%
# Specify the target size for images
img_size = 48
# Set the batch size
batch_size = 64

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator
# Define the preprocessing parameters for data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    shear_range=0.1,
    zoom_range=0.1,    
    height_shift_range = 0.1,
    width_shift_range = 0.1,
    horizontal_flip=True,
    fill_mode='nearest', 
    validation_split=0.2
)

test_datagen = ImageDataGenerator(rescale = 1./ 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    color_mode='grayscale',
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
    subset = 'training'
)

validation_generator = train_datagen.flow_from_directory(
    train_data_dir,
    color_mode='grayscale',
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False,
    subset = 'validation' 
)

test_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    color_mode='grayscale',
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ### Creating the model

# %%
# https://www.tensorflow.org/guide/keras/sequential_model
model = Sequential()
model.add(Input(shape=(img_size, img_size, 1)))
model.add(Conv2D(64, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(128, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(7, activation='softmax'))

# %% [markdown]
# #### Model summary

# %%
# Compile the model
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# model summary
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)                   │ (None, 48, 48, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_14               │ (None, 48, 48, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 48, 48, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_15               │ (None, 48, 48, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 24, 24, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_16               │ (None, 24, 24, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_15 (Conv2D)                   │ (None, 24, 24, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_17               │ (None, 24, 24, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_16 (Conv2D)                   │ (None, 12, 12, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_18               │ (None, 12, 12, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 12, 12, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_19               │ (None, 12, 12, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 9216)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 512)                 │       4,719,104 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_20               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 7)                   │           3,591 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,872,583 (22.40 MB)
#  Trainable params: 5,869,767 (22.39 MB)
#  Non-trainable params: 2,816 (11.00 KB)

# %% [markdown]
# #### Defining callbacks

# %%
# https://keras.io/api/callbacks/
# define callbacks
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Monitor validation loss
    factor=0.5,             # Reduce LR by 0.5
    patience=5,             # Wait 5 epochs with no improvement before reducing LR
    min_lr=1e-5,            # Minimum LR value
    verbose=1               # Display messages when learning rate is reduced
)

early_stopping = EarlyStopping(
    monitor="val_loss",        # Monitor validation loss
    patience=10,               # Stop after 10 epochs with no improvement
    verbose=1,                 # Display message when training is stopped
    restore_best_weights=True, # Restore best model weights
    min_delta=0.0001           # Consider significant changes
)

callbacks = [reduce_lr, early_stopping]

# %% [markdown]
# #### Model training

# %%
# https://www.tensorflow.org/guide/keras/training_with_built_in_methods
# Train the model
epochs = 80
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    callbacks = callbacks,
    verbose=1

)

# Save the model
model.save('/kaggle/working/new_model.h5')
# Out:
# Epoch 1/80
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 52s 110ms/step - accuracy: 0.2298 - loss: 2.3050 - val_accuracy: 0.1843 - val_loss: 1.9591 - learning_rate: 0.0010
# Epoch 2/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 93ms/step - accuracy: 0.3189 - loss: 1.7927 - val_accuracy: 0.3606 - val_loss: 1.6135 - learning_rate: 0.0010
# Epoch 3/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 95ms/step - accuracy: 0.4215 - loss: 1.5056 - val_accuracy: 0.4539 - val_loss: 1.4175 - learning_rate: 0.0010
# Epoch 4/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 96ms/step - accuracy: 0.4809 - loss: 1.3522 - val_accuracy: 0.4349 - val_loss: 1.5422 - learning_rate: 0.0010
# Epoch 5/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 95ms/step - accuracy: 0.5110 - loss: 1.2785 - val_accuracy: 0.4748 - val_loss: 1.3711 - learning_rate: 0.0010
# Epoch 6/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 95ms/step - accuracy: 0.5333 - loss: 1.2276 - val_accuracy: 0.4750 - val_loss: 1.3948 - learning_rate: 0.0010
# Epoch 7/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 33s 91ms/step - accuracy: 0.5402 - loss: 1.2020 - val_accuracy: 0.5346 - val_loss: 1.2366 - learning_rate: 0.0010
# Epoch 8/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 94ms/step - accuracy: 0.5670 - loss: 1.1475 - val_accuracy: 0.5011 - val_loss: 1.2881 - learning_rate: 0.0010
# Epoch 9/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 33s 92ms/step - accuracy: 0.5702 - loss: 1.1275 - val_accuracy: 0.5452 - val_loss: 1.1863 - learning_rate: 0.0010
# Epoch 10/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 96ms/step - accuracy: 0.5894 - loss: 1.0936 - val_accuracy: 0.5316 - val_loss: 1.2193 - learning_rate: 0.0010
# Epoch 11/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 93ms/step - accuracy: 0.5946 - loss: 1.0687 - val_accuracy: 0.5600 - val_loss: 1.1592 - learning_rate: 0.0010
# Epoch 12/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 95ms/step - accuracy: 0.6027 - loss: 1.0569 - val_accuracy: 0.5685 - val_loss: 1.1457 - learning_rate: 0.0010
# Epoch 13/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 99ms/step - accuracy: 0.6023 - loss: 1.0486 - val_accuracy: 0.5945 - val_loss: 1.0928 - learning_rate: 0.0010
# Epoch 14/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 97ms/step - accuracy: 0.6012 - loss: 1.0528 - val_accuracy: 0.5835 - val_loss: 1.0871 - learning_rate: 0.0010
# Epoch 15/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 94ms/step - accuracy: 0.6107 - loss: 1.0248 - val_accuracy: 0.5954 - val_loss: 1.0788 - learning_rate: 0.0010
# Epoch 16/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.6130 - loss: 1.0295 - val_accuracy: 0.5590 - val_loss: 1.1704 - learning_rate: 0.0010
# Epoch 17/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 94ms/step - accuracy: 0.6201 - loss: 1.0131 - val_accuracy: 0.5807 - val_loss: 1.1086 - learning_rate: 0.0010
# Epoch 18/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 94ms/step - accuracy: 0.6313 - loss: 0.9731 - val_accuracy: 0.5905 - val_loss: 1.0858 - learning_rate: 0.0010
# Epoch 19/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 33s 92ms/step - accuracy: 0.6311 - loss: 0.9749 - val_accuracy: 0.6018 - val_loss: 1.0693 - learning_rate: 0.0010
# Epoch 20/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 94ms/step - accuracy: 0.6357 - loss: 0.9645 - val_accuracy: 0.5935 - val_loss: 1.0866 - learning_rate: 0.0010
# Epoch 21/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.6437 - loss: 0.9469 - val_accuracy: 0.5847 - val_loss: 1.1139 - learning_rate: 0.0010
# Epoch 22/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 93ms/step - accuracy: 0.6473 - loss: 0.9423 - val_accuracy: 0.5957 - val_loss: 1.0682 - learning_rate: 0.0010
# Epoch 23/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 93ms/step - accuracy: 0.6539 - loss: 0.9147 - val_accuracy: 0.6196 - val_loss: 1.0053 - learning_rate: 0.0010
# Epoch 24/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 95ms/step - accuracy: 0.6522 - loss: 0.9129 - val_accuracy: 0.5750 - val_loss: 1.1258 - learning_rate: 0.0010
# Epoch 25/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 92ms/step - accuracy: 0.6514 - loss: 0.9261 - val_accuracy: 0.6227 - val_loss: 1.0424 - learning_rate: 0.0010
# Epoch 26/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 94ms/step - accuracy: 0.6595 - loss: 0.9051 - val_accuracy: 0.6211 - val_loss: 1.0393 - learning_rate: 0.0010
# Epoch 27/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 93ms/step - accuracy: 0.6634 - loss: 0.8905 - val_accuracy: 0.6238 - val_loss: 1.0293 - learning_rate: 0.0010
# Epoch 28/80
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6584 - loss: 0.9146
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 95ms/step - accuracy: 0.6584 - loss: 0.9146 - val_accuracy: 0.6147 - val_loss: 1.0276 - learning_rate: 0.0010
# Epoch 29/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 95ms/step - accuracy: 0.6693 - loss: 0.8754 - val_accuracy: 0.6360 - val_loss: 0.9928 - learning_rate: 5.0000e-04
# Epoch 30/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 33s 91ms/step - accuracy: 0.6813 - loss: 0.8494 - val_accuracy: 0.6396 - val_loss: 0.9781 - learning_rate: 5.0000e-04
# Epoch 31/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 95ms/step - accuracy: 0.6930 - loss: 0.8193 - val_accuracy: 0.6307 - val_loss: 0.9964 - learning_rate: 5.0000e-04
# Epoch 32/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 94ms/step - accuracy: 0.6948 - loss: 0.8181 - val_accuracy: 0.6471 - val_loss: 0.9876 - learning_rate: 5.0000e-04
# Epoch 33/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 95ms/step - accuracy: 0.6959 - loss: 0.8113 - val_accuracy: 0.6495 - val_loss: 0.9700 - learning_rate: 5.0000e-04
# Epoch 34/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 95ms/step - accuracy: 0.6928 - loss: 0.8166 - val_accuracy: 0.6464 - val_loss: 0.9778 - learning_rate: 5.0000e-04
# Epoch 35/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 93ms/step - accuracy: 0.7044 - loss: 0.7871 - val_accuracy: 0.6407 - val_loss: 0.9759 - learning_rate: 5.0000e-04
# Epoch 36/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 95ms/step - accuracy: 0.7141 - loss: 0.7677 - val_accuracy: 0.6438 - val_loss: 0.9819 - learning_rate: 5.0000e-04
# Epoch 37/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 33s 92ms/step - accuracy: 0.7052 - loss: 0.7757 - val_accuracy: 0.6576 - val_loss: 0.9677 - learning_rate: 5.0000e-04
# Epoch 38/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 98ms/step - accuracy: 0.7174 - loss: 0.7582 - val_accuracy: 0.6380 - val_loss: 1.0033 - learning_rate: 5.0000e-04
# Epoch 39/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 92ms/step - accuracy: 0.7062 - loss: 0.7699 - val_accuracy: 0.6495 - val_loss: 0.9698 - learning_rate: 5.0000e-04
# Epoch 40/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 94ms/step - accuracy: 0.7102 - loss: 0.7661 - val_accuracy: 0.6487 - val_loss: 0.9896 - learning_rate: 5.0000e-04
# Epoch 41/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 37s 100ms/step - accuracy: 0.7211 - loss: 0.7501 - val_accuracy: 0.6494 - val_loss: 0.9977 - learning_rate: 5.0000e-04
# Epoch 42/80
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7201 - loss: 0.7540
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 99ms/step - accuracy: 0.7201 - loss: 0.7540 - val_accuracy: 0.6506 - val_loss: 1.0062 - learning_rate: 5.0000e-04
# Epoch 43/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 93ms/step - accuracy: 0.7263 - loss: 0.7400 - val_accuracy: 0.6565 - val_loss: 0.9683 - learning_rate: 2.5000e-04
# Epoch 44/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 95ms/step - accuracy: 0.7349 - loss: 0.7190 - val_accuracy: 0.6584 - val_loss: 0.9612 - learning_rate: 2.5000e-04
# Epoch 45/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 94ms/step - accuracy: 0.7346 - loss: 0.7080 - val_accuracy: 0.6656 - val_loss: 0.9486 - learning_rate: 2.5000e-04
# Epoch 46/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 93ms/step - accuracy: 0.7403 - loss: 0.6966 - val_accuracy: 0.6612 - val_loss: 0.9705 - learning_rate: 2.5000e-04
# Epoch 47/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 92ms/step - accuracy: 0.7416 - loss: 0.6877 - val_accuracy: 0.6492 - val_loss: 0.9764 - learning_rate: 2.5000e-04
# Epoch 48/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 94ms/step - accuracy: 0.7443 - loss: 0.6803 - val_accuracy: 0.6558 - val_loss: 0.9748 - learning_rate: 2.5000e-04
# Epoch 49/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 93ms/step - accuracy: 0.7356 - loss: 0.7017 - val_accuracy: 0.6546 - val_loss: 0.9917 - learning_rate: 2.5000e-04
# Epoch 50/80
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7438 - loss: 0.6807
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 96ms/step - accuracy: 0.7438 - loss: 0.6807 - val_accuracy: 0.6614 - val_loss: 0.9702 - learning_rate: 2.5000e-04
# Epoch 51/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 93ms/step - accuracy: 0.7449 - loss: 0.6748 - val_accuracy: 0.6650 - val_loss: 0.9685 - learning_rate: 1.2500e-04
# Epoch 52/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 98ms/step - accuracy: 0.7554 - loss: 0.6603 - val_accuracy: 0.6652 - val_loss: 0.9622 - learning_rate: 1.2500e-04
# Epoch 53/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 100ms/step - accuracy: 0.7514 - loss: 0.6684 - val_accuracy: 0.6645 - val_loss: 0.9702 - learning_rate: 1.2500e-04
# Epoch 54/80
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 97ms/step - accuracy: 0.7562 - loss: 0.6578 - val_accuracy: 0.6598 - val_loss: 0.9740 - learning_rate: 1.2500e-04
# Epoch 55/80
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7568 - loss: 0.6500
# Epoch 55: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 95ms/step - accuracy: 0.7568 - loss: 0.6500 - val_accuracy: 0.6668 - val_loss: 0.9728 - learning_rate: 1.2500e-04
# Epoch 55: early stopping
# Restoring model weights from the end of the best epoch: 45.

# %% [markdown]
# ### Results and Evaluation
# ##### 1. Accuracy

# %%
# Evaluation of the model on the sets
train_loss,train_acc=model.evaluate(train_generator)
val_loss,val_acc=model.evaluate(validation_generator)
test_loss, test_acc = model.evaluate(test_generator)
print("Training Accuracy:{:.2f}%".format(train_acc*100))
print("Validation Accuracy:{:.2f}%".format(val_acc*100))
print("Test Accuracy:{:.2f}%".format(test_acc*100))
# Out:
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 28s 77ms/step - accuracy: 0.7823 - loss: 0.5973
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.6038 - loss: 1.1307
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.6311 - loss: 1.0654
# Training Accuracy:77.89%
# Validation Accuracy:66.43%
# Test Accuracy:67.75%

# %% [markdown]
# #### 2. Accuracy and Loss graphs

# %%
# Plot the graphs
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### 3. Classification Report

# %%
# Load the trained model
model = load_model("/kaggle/working/new_model.h5")

# Load validation data, class names and the true labels
y_true = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# Get predictions
y_pred = model.predict(test_generator)
y_pred = np.argmax(y_pred, axis=1)

# Print classification report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.62      0.60      0.61       958
#      disgust       0.75      0.45      0.56       111
#         fear       0.58      0.42      0.48      1024
#        happy       0.86      0.89      0.87      1774
#      neutral       0.58      0.70      0.64      1233
#          sad       0.55      0.59      0.57      1247
#     surprise       0.79      0.76      0.78       831
#
#     accuracy                           0.68      7178
#    macro avg       0.68      0.63      0.64      7178
# weighted avg       0.68      0.68      0.67      7178

# %% [markdown]
# #### 4. a. Confusion Matrix A

# %%
#Load the trained model and evaluate it when the shuffle is set to True in the test generator
# Load the trained model
model = load_model("/kaggle/working/new_model.h5")

# Get the true labels from the test generator
y_true = test_generator.classes 
# Class names
labels = list(test_generator.class_indices.keys()) 

# Get predictions
y_pred = model.predict(test_generator)
# Convert to class labels
y_pred = np.argmax(y_pred, axis=1)  
# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 8))

sns.heatmap(cm, 
            annot=True, 
            fmt="d", 
            cmap="Purples", 
            xticklabels=labels, 
            yticklabels=labels)

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix",fontsize=13)
plt.show()
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step

# %% [markdown]
# #### 4. b. Confusion Matrix B

# %%
#Load the trained model and evaluate it when the shuffle is set to False in the test generator
#Load the trained model
model = load_model("/kaggle/working/new_model.h5")

# Get the true labels from the test generator
y_true = test_generator.classes 
# Class names
labels = list(test_generator.class_indices.keys()) 

# Get predictions
y_pred = model.predict(test_generator)
# Convert to class labels
y_pred = np.argmax(y_pred, axis=1)  
# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 8))

sns.heatmap(cm, 
            annot=True, 
            fmt="d", 
            cmap="Blues", 
            xticklabels=labels, 
            yticklabels=labels)

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix",fontsize=13)
plt.show()
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step

# %% [markdown]
# ### Model Structure

# %%
# Model structure
from tensorflow.keras.utils import plot_model

plot_model(model, to_file="model.png", show_shapes=False, show_layer_names=False, dpi=80)
